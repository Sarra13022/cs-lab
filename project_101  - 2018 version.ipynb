# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("coteq_electricity_2018.csv")
df1.head()
# Out:
#           net_manager                          purchase_area         street  \
# 0  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.    Dorpsstraat
# 1  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 2  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 3  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.  De Stoevelaar
# 4  Coteq Netbeheer BV  Netbeheerder Centraal Overijssel B.V.     Kerkstraat
#
#   zipcode_from zipcode_to   city  num_connections  delivery_perc  \
# 0       7468CP     7471AA  ENTER               19          89.47
# 1       7471AB     7471AB   GOOR               37         100.00
# 2       7471AC     7471AC   GOOR               16         100.00
# 3       7471AD     7471AE   GOOR               25          92.00
# 4       7471AG     7471AG   GOOR               14          85.71
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                       94.74              89               1x35
# 1                      100.00              86               1x35
# 2                      100.00             100               1x35
# 3                       84.00              44               1x35
# 4                      100.00              36               1x35
#
#    annual_consume  annual_consume_lowtarif_perc  smartmeter_perc
# 0            4122                         89.47              0.0
# 1            1800                         94.59              0.0
# 2            1315                        100.00              0.0
# 3            6379                         92.00              0.0
# 4            4404                         92.86              0.0

# %%
missing_data = df1.isnull()
missing_data.head(5)                         #no missing data
# Out:
#    net_manager  purchase_area  street  zipcode_from  zipcode_to   city  \
# 0        False          False   False         False       False  False
# 1        False          False   False         False       False  False
# 2        False          False   False         False       False  False
# 3        False          False   False         False       False  False
# 4        False          False   False         False       False  False
#
#    num_connections  delivery_perc  perc_of_active_connections  type_conn_perc  \
# 0            False          False                       False           False
# 1            False          False                       False           False
# 2            False          False                       False           False
# 3            False          False                       False           False
# 4            False          False                       False           False
#
#    type_of_connection  annual_consume  annual_consume_lowtarif_perc  \
# 0               False           False                         False
# 1               False           False                         False
# 2               False           False                         False
# 3               False           False                         False
# 4               False           False                         False
#
#    smartmeter_perc
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
df1.describe()
# Out:
#        num_connections  delivery_perc  perc_of_active_connections  \
# count      2503.000000    2503.000000                 2503.000000
# mean         21.007591      95.163811                   98.571506
# std           9.936345       8.075571                    8.146253
# min          10.000000      14.810000                    0.000000
# 25%          15.000000      92.310000                  100.000000
# 50%          19.000000     100.000000                  100.000000
# 75%          24.000000     100.000000                  100.000000
# max         127.000000     100.000000                  100.000000
#
#        type_conn_perc  annual_consume  annual_consume_lowtarif_perc  \
# count     2503.000000     2503.000000                   2503.000000
# mean        78.941670     4090.971235                     87.308122
# std         18.685365     3341.049444                     16.178740
# min         23.000000        0.000000                      0.000000
# 25%         64.000000     2705.500000                     80.000000
# 50%         83.000000     3268.000000                     92.860000
# 75%         95.000000     4024.500000                    100.000000
# max        100.000000    50460.000000                    100.000000
#
#        smartmeter_perc
# count      2503.000000
# mean          0.004327
# std           0.128091
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           4.760000

# %%
del df1 ["delivery_perc"]

# %%
del df1 ["purchase_area"]

# %%
del df1 ["zipcode_from"]

# %%
del df1 ["zipcode_to"]

# %%
del df1 ["perc_of_active_connections"]

# %%
del df1 ["type_conn_perc"]

# %%
del df1 ["smartmeter_perc"]

# %%
del df1 ["num_connections"]

# %%
del df1 ["type_of_connection"]

# %%
df1.head()
# Out:
#           net_manager         street   city  annual_consume  \
# 0  Coteq Netbeheer BV    Dorpsstraat  ENTER            4122
# 1  Coteq Netbeheer BV  De Stoevelaar   GOOR            1800
# 2  Coteq Netbeheer BV  De Stoevelaar   GOOR            1315
# 3  Coteq Netbeheer BV  De Stoevelaar   GOOR            6379
# 4  Coteq Netbeheer BV     Kerkstraat   GOOR            4404
#
#    annual_consume_lowtarif_perc
# 0                         89.47
# 1                         94.59
# 2                        100.00
# 3                         92.00
# 4                         92.86

# %%
df1.columns = ['net_manager', 'street', 'city', 'annual_consume','annual_consume_lowtarif_perc']
#df.loc[df['city'] == "GOOR", 'annual_consume'].sum()

# %%
df1.head()
# Out:
#           net_manager         street   city  annual_consume  \
# 0  Coteq Netbeheer BV    Dorpsstraat  ENTER            4122
# 1  Coteq Netbeheer BV  De Stoevelaar   GOOR            1800
# 2  Coteq Netbeheer BV  De Stoevelaar   GOOR            1315
# 3  Coteq Netbeheer BV  De Stoevelaar   GOOR            6379
# 4  Coteq Netbeheer BV     Kerkstraat   GOOR            4404
#
#    annual_consume_lowtarif_perc
# 0                         89.47
# 1                         94.59
# 2                        100.00
# 3                         92.00
# 4                         92.86

# %%
df1.loc[df1['city'] == "GOOR", 'annual_consume'].sum()
# Out:
# 1119848

# %%
df1.loc[df1['city'] == "OLDENZAAL", 'annual_consume'].sum()
# Out:
# 3006420

# %%
df1.loc[df1['city'] == "ALMELO", 'annual_consume'].sum()
# Out:
# 6109311

# %%
df2 = pd.read_csv("enexis_electricity_01012018.csv")
df2.head()
# Out:
#    net_manager purchase_area     street zipcode_from zipcode_to       city  \
# 0  Enexis B.V.        ENEXIS    Sasdijk       4251AA     4251AA  WERKENDAM
# 1  Enexis B.V.        ENEXIS    Sasdijk       4251AB     4251AB  WERKENDAM
# 2  Enexis B.V.        ENEXIS    Sasdijk       4251AC     4251AC  WERKENDAM
# 3  Enexis B.V.        ENEXIS    Sasdijk       4251AD     4251AD  WERKENDAM
# 4  Enexis B.V.        ENEXIS  Heuveltje       4251AE     4251AG  WERKENDAM
#
#    num_connections  delivery_perc  perc_of_active_connections  type_conn_perc  \
# 0               42         100.00                         100           50.00
# 1               17         100.00                         100           41.18
# 2               11          81.82                         100           63.64
# 3               29         100.00                         100           41.38
# 4               21          90.48                         100           42.86
#
#   type_of_connection  annual_consume  annual_consume_lowtarif_perc  \
# 0               3x25         5860.21                         28.31
# 1               1x25         4149.24                         28.33
# 2               1x25         2389.27                         34.60
# 3               3x25         3866.21                         32.11
# 4               1x25         4416.52                         57.26
#
#    smartmeter_perc
# 0             7.14
# 1            29.41
# 2            36.36
# 3            17.24
# 4            33.33

# %%
df3 = pd.read_csv("liander_electricity_01012018.csv")
df3.head()
# Out:
#          net_manager  purchase_area                  street zipcode_from  \
# 0  Liander N.V. (NW)            NaN  De Ruyterkade Steigers       1011AA
# 1  Liander N.V. (NW)            NaN           De Ruyterkade       1011AC
# 2  Liander N.V. (NW)            NaN          Oosterdokskade       1011AD
# 3  Liander N.V. (NW)            NaN       Oosterdokskade AB       1011AE
# 4  Liander N.V. (NW)            NaN       Prins Hendrikkade       1011AG
#
#   zipcode_to       city  num_connections  delivery_perc  \
# 0     1011AB  AMSTERDAM               35          100.0
# 1     1011AC  AMSTERDAM               39          100.0
# 2     1011AD  AMSTERDAM               19          100.0
# 3     1011AE  AMSTERDAM               19          100.0
# 4     1011AG  AMSTERDAM               14          100.0
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                       34.29              31               3x25
# 1                       56.41              28               3x80
# 2                        5.26              58               3x25
# 3                       10.53              63               3x25
# 4                       92.86              29               1x35
#
#    annual_consume  annual_consume_lowtarif_perc  smartmeter_perc
# 0           14403                         40.00            22.86
# 1           18739                         41.03            28.21
# 2            4026                         47.37             0.00
# 3            3184                         31.58             5.26
# 4           20376                         50.00            35.71

# %%
df3.loc[df3['city'] == "AMSTERDAM", 'annual_consume'].sum()
# Out:
# 55010230

# %%
df4 = pd.read_csv("stedin_electricity_2018.csv")
df4.head()
# Out:
#      net_manager   purchase_area                   street zipcode_from  \
# 0  8716874000009  Stedin Utrecht  Gijsbrecht van Amstelln       1181EJ
# 1  8716874000009  Stedin Utrecht            Rembrandtlaan       1231AC
# 2  8716874000009  Stedin Utrecht            Rembrandtlaan       1231AD
# 3  8716874000009  Stedin Utrecht            Jan Steenlaan       1231AE
# 4  8716874000009  Stedin Utrecht      Pieter de Hooghlaan       1231AG
#
#   zipcode_to        city  num_connections  delivery_perc  \
# 0     1231AB  AMSTELVEEN               33          93.94
# 1     1231AC  LOOSDRECHT               17         100.00
# 2     1231AD  LOOSDRECHT               17         100.00
# 3     1231AE  LOOSDRECHT               20         100.00
# 4     1231AG  LOOSDRECHT               17          94.12
#
#    perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                       90.91            76.0               3x25
# 1                      100.00            41.0               1x25
# 2                      100.00            47.0               3x25
# 3                      100.00            45.0               3x25
# 4                      100.00            71.0               1x25
#
#    annual_consume  annual_consume_lowtarif_perc  smartmeter_perc
# 0            5926                         84.85            21.21
# 1            3149                         76.47            17.65
# 2            3906                         76.47             5.88
# 3            4696                         85.00            15.00
# 4            3557                         64.71             5.88

# %%
df5 = pd.read_csv("westland-infra_electricity_2018.csv")
df5                       #prob
# Out:
#          net_manager       purchase_area               street zipcode_from  \
# 0     westland-infra  871687800090000015            OOSTEINDE       2291AA
# 1     westland-infra  871687800090000015            WATERPARK       2291AK
# 2     westland-infra  871687800090000015           AZALEAPARK       2291AL
# 3     westland-infra  871687800090000015          DRUIVENLAAN       2291AN
# 4     westland-infra  871687800090000015             KWAKLAAN       2291AV
# ...              ...                 ...                  ...          ...
# 2513  westland-infra  871687800090000015         IN DE BALIJE       3155XA
# 2514  westland-infra  871687800090000015  KONINGIN JULIANAWEG       3155XB
# 2515  westland-infra  871687800090000015  KONINGIN JULIANAWEG       3155XC
# 2516  westland-infra  871687800090000015  KONINGIN JULIANAWEG       3155XE
# 2517  westland-infra  871687800090000015           MERESTEIJN       3155XJ
#
#      zipcode_to        city  delivery_perc  perc_of_active_connections  \
# 0        2291AE  WATERINGEN          89.66                      100.00
# 1        2291AK  WATERINGEN          87.50                      100.00
# 2        2291AL  WATERINGEN         100.00                      100.00
# 3        2291AT  WATERINGEN          69.05                       97.62
# 4        2291AV  WATERINGEN         100.00                      100.00
# ...         ...         ...            ...                         ...
# 2513     3155XA    MAASLAND         100.00                      100.00
# 2514     3155XB    MAASLAND         100.00                      100.00
# 2515     3155XD    MAASLAND          86.21                      100.00
# 2516     3155XH    MAASLAND          82.14                      100.00
# 2517     3155XK    MAASLAND          78.95                      100.00
#
#       %Defintieve aansl (NRM)  type_conn_perc type_of_connection  \
# 0                         100              59               3x25
# 1                         100              63               1x35
# 2                         100              86               1x35
# 3                         100              71               3x25
# 4                         100              81               1x35
# ...                       ...             ...                ...
# 2513                      100              93               3x25
# 2514                      100              79               3x25
# 2515                      100              76               3x25
# 2516                      100              82               3x25
# 2517                      100              95               3x25
#
#       annual_consume  annual_consume_lowtarif_perc  smartmeter_perc  \
# 0               7029                         96.55            72.41
# 1               5411                        100.00            82.50
# 2               3239                        100.00            96.55
# 3               5364                        100.00            88.10
# 4               2949                        100.00            87.50
# ...              ...                           ...              ...
# 2513            6799                        100.00            21.43
# 2514            4799                         92.86            21.43
# 2515            6113                         89.66            24.14
# 2516            3724                        100.00            28.57
# 2517            5518                        100.00            26.32
#
#       num_connections
# 0                  29
# 1                  40
# 2                  29
# 3                  42
# 4                  16
# ...               ...
# 2513               14
# 2514               14
# 2515               29
# 2516               28
# 2517               19
#
# [2518 rows x 15 columns]

# %%
del df2 ["delivery_perc"]

# %%
del df2 ["zipcode_from"]

# %%
del df2 ["zipcode_to"]

# %%
del df2 ["num_connections"]

# %%
del df2 ["smartmeter_perc"]

# %%
del df2 ["perc_of_active_connections"]

# %%
del df2 ["type_of_connection"]

# %%
del df2 ["type_conn_perc"]

# %%
df2.info
# Out:
# <bound method DataFrame.info of         net_manager purchase_area                street       city  \
# 0       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 1       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 2       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 3       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 4       Enexis B.V.        ENEXIS             Heuveltje  WERKENDAM
# ...             ...           ...                   ...        ...
# 124158  Enexis B.V.        ENEXIS  Jacob Tilbusscherweg  ROTTUM GN
# 124159  Enexis B.V.        ENEXIS           Jan Boerweg  ROTTUM GN
# 124160  Enexis B.V.        ENEXIS               Knolweg  ROTTUM GN
# 124161  Enexis B.V.        ENEXIS        Stitswerderweg  STITSWERD
# 124162  Enexis B.V.        ENEXIS                 Stiel  STITSWERD
#
#         annual_consume  annual_consume_lowtarif_perc
# 0              5860.21                         28.31
# 1              4149.24                         28.33
# 2              2389.27                         34.60
# 3              3866.21                         32.11
# 4              4416.52                         57.26
# ...                ...                           ...
# 124158         7307.86                         50.38
# 124159         2447.10                         46.38
# 124160        14804.69                         54.92
# 124161         7429.94                         40.77
# 124162         2608.67                         46.53
#
# [124163 rows x 6 columns]>

# %%
df2
# Out:
#         net_manager purchase_area                street       city  \
# 0       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 1       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 2       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 3       Enexis B.V.        ENEXIS               Sasdijk  WERKENDAM
# 4       Enexis B.V.        ENEXIS             Heuveltje  WERKENDAM
# ...             ...           ...                   ...        ...
# 124158  Enexis B.V.        ENEXIS  Jacob Tilbusscherweg  ROTTUM GN
# 124159  Enexis B.V.        ENEXIS           Jan Boerweg  ROTTUM GN
# 124160  Enexis B.V.        ENEXIS               Knolweg  ROTTUM GN
# 124161  Enexis B.V.        ENEXIS        Stitswerderweg  STITSWERD
# 124162  Enexis B.V.        ENEXIS                 Stiel  STITSWERD
#
#         annual_consume  annual_consume_lowtarif_perc
# 0              5860.21                         28.31
# 1              4149.24                         28.33
# 2              2389.27                         34.60
# 3              3866.21                         32.11
# 4              4416.52                         57.26
# ...                ...                           ...
# 124158         7307.86                         50.38
# 124159         2447.10                         46.38
# 124160        14804.69                         54.92
# 124161         7429.94                         40.77
# 124162         2608.67                         46.53
#
# [124163 rows x 6 columns]

# %%
dg1 = df1.groupby('city').sum()

# %%
dg1
# Out:
#            annual_consume  annual_consume_lowtarif_perc
# city
# ALMELO            6109311                     130584.84
# ENTER                4122                         89.47
# GOOR              1119848                      25675.84
# OLDENZAAL         3006420                      62182.08

# %%
dg2 = df2.groupby('city').sum()

# %%
dg2
# Out:
#                   annual_consume  annual_consume_lowtarif_perc
# city
# 'S GRAVENMOER          220627.40                       1548.17
# 'S-HEERENBROEK          60812.62                        404.22
# 'S-HERTOGENBOSCH      9911160.77                     110406.72
# 'T HAANTJE              15150.79                        169.58
# 'T WAAR                 18360.97                        208.31
# ...                          ...                           ...
# ZWARTSLUIS             518601.75                       5400.36
# ZWEELOO                 76394.60                        384.93
# ZWIGGELTE              109407.67                        502.16
# ZWINDEREN               72314.23                        467.22
# ZWOLLE               10652261.29                     107367.47
#
# [1057 rows x 2 columns]

# %%
del df3 ["delivery_perc"]

# %%
del df4 ["delivery_perc"]

# %%
del df5 ["delivery_perc"]

# %%
del df3 ["num_connections"]

# %%
del df4 ["num_connections"]

# %%
del df5 ["num_connections"]

# %%
del df3 ["perc_of_active_connections"]

# %%
del df4 ["perc_of_active_connections"]

# %%
del df5 ["perc_of_active_connections"]

# %%
del df3 ["type_conn_perc"]

# %%
del df4 ["type_conn_perc"]

# %%
del df5 ["type_conn_perc"]

# %%
del df3 ["smartmeter_perc"]

# %%
del df4 ["smartmeter_perc"]

# %%
del df5 ["smartmeter_perc"]

# %%
del df5 ["%Defintieve aansl (NRM)"]

# %%
del df5 ["purchase_area"]

# %%
del df3 ["purchase_area"]

# %%
dg3 = df3.groupby('city').sum()

# %%
dg3
# Out:
#                   annual_consume  annual_consume_lowtarif_perc
# city
# 'S-GRAVELAND              212734                       1842.42
# 'S-GRAVENHAGE               6349                         80.77
# 'S-HEERENBERG             902793                      11067.61
# 'T HARDE                  596999                       6548.08
# 'T LOO OLDEBROEK           98599                        966.84
# ...                          ...                           ...
# ZWANENBURG                797886                       9602.44
# ZWARTEBROEK               212028                       1636.36
# ZWEINS                     16678                        199.36
# Zwaagdijk-Oost              5889                         61.70
# loo                         4607                         46.15
#
# [1104 rows x 2 columns]

# %%
del df4 ["net_manager"]

# %%
dg4 = df4.groupby('city').sum()

# %%
dg4
# Out:
#                  annual_consume  annual_consume_lowtarif_perc
# city
# 'S-GRAVENDEEL            688381                      17091.30
# 'S-GRAVENHAGE          40033251                     751415.61
# 'S-GRAVENZANDE             8412                         63.64
# 'SâGRAVENHAGE            1991                         42.86
# 'T GOY                   101420                       1295.50
# ...                         ...                           ...
# ZOETERMEER             10314442                     253068.50
# ZUID-BEIJERLAND          305923                       6940.71
# ZUIDLAND                 409632                       9591.99
# ZWARTEWAAL               200555                       4185.68
# ZWIJNDRECHT             2616741                      67342.81
#
# [265 rows x 2 columns]

# %%
dg5 = df5.groupby('city').sum()

# %%
dg5
# Out:
#                   annual_consume  annual_consume_lowtarif_perc
# city
# 'S-GRAVENZANDE           2156463                      42574.15
# DE LIER                  1255307                      22178.76
# DELFT                     211198                       5687.72
# DEN HOORN                  13746                         88.89
# DEN HOORN ZH              531641                      12687.88
# HOEK VAN HOLLAND            3104                         98.86
# HONSELERSDIJK             861417                      12022.82
# KWINTSHEUL                395063                       7606.57
# MAASDIJK                  586749                       7281.63
# MAASLAND                  613027                      11408.64
# MAASSLUIS                  13414                        293.75
# MONSTER                  1300654                      23890.01
# NAALDWIJK                1915035                      33807.64
# POELDIJK                  639608                      12980.94
# SCHIPLUIDEN               391853                       7192.10
# TER HEIJDE                 42443                        834.41
# VLAARDINGEN                 7022                         95.59
# WATERINGEN               1267715                      28745.33

# %%
dfp = pd.read_excel("data1.xlsx")
dfp
# Out:
#              city  population   surface (km2)   Density
# 0          ALMELO      72.8490          69.41   1.049546
# 1       OLDENZAAL      31.8400          21.95   1.450569
# 2           GOORÿ      12.3140           9.10   1.353187
# 3       EINDHOVEN     223.2090          88.92   2.510223
# 4      GRONINGEN      200.3360         198.00        NaN
# 5        ENSCHEDE     158.5530         118.13   1.342191
# 6         TILBURG     217.2590         142.70   1.522488
# 7          ZWOLLE     123.8610         119.40   1.037362
# 8       AMSTERDAM     821.7520         219.30   3.747159
# 9          ALMERE     196.9320         248.80   0.791527
# 10        HAARLEM     235.1410          32.09   7.327548
# 11       NIJMEGEN     170.6810          57.63   2.961669
# 12        ARNHEM      152.2930         101.50   1.500424
# 13  S-GRAVENHAGE      514.8610          98.13   5.246724
# 14      ROTTERDAM     623.6520         324.10   1.924258
# 15        UTRECHT    1300.3658          63.86  20.362759
# 16     AMERSFOORT     152.4810          37.05   4.115547
# 17     ZOETERMEER     124.0250          98.13   1.263885
# 18      NAALDWIJK      18.8580           9.01   2.093008
# 19        MONSTER      11.5800           9.00   1.286667
# 20     WATERINGEN      10.8600           8.90   1.220225
# 21        DE LIER      11.9250           8.92   1.336883

# %%
dg11=dg1.append(dg2)

# %%
dg11
# Out:
#                annual_consume  annual_consume_lowtarif_perc
# city
# ALMELO             6109311.00                     130584.84
# ENTER                 4122.00                         89.47
# GOOR               1119848.00                      25675.84
# OLDENZAAL          3006420.00                      62182.08
# 'S GRAVENMOER       220627.40                       1548.17
# ...                       ...                           ...
# ZWARTSLUIS          518601.75                       5400.36
# ZWEELOO              76394.60                        384.93
# ZWIGGELTE           109407.67                        502.16
# ZWINDEREN            72314.23                        467.22
# ZWOLLE            10652261.29                     107367.47
#
# [1061 rows x 2 columns]

# %%
dg111=dg11.append(dg3)

# %%
dg111
# Out:
#                 annual_consume  annual_consume_lowtarif_perc
# city
# ALMELO               6109311.0                     130584.84
# ENTER                   4122.0                         89.47
# GOOR                 1119848.0                      25675.84
# OLDENZAAL            3006420.0                      62182.08
# 'S GRAVENMOER         220627.4                       1548.17
# ...                        ...                           ...
# ZWANENBURG            797886.0                       9602.44
# ZWARTEBROEK           212028.0                       1636.36
# ZWEINS                 16678.0                        199.36
# Zwaagdijk-Oost          5889.0                         61.70
# loo                     4607.0                         46.15
#
# [2165 rows x 2 columns]

# %%
dg1111=dg111.append(dg4)

# %%
dg1111
# Out:
#                  annual_consume  annual_consume_lowtarif_perc
# city
# ALMELO                6109311.0                     130584.84
# ENTER                    4122.0                         89.47
# GOOR                  1119848.0                      25675.84
# OLDENZAAL             3006420.0                      62182.08
# 'S GRAVENMOER          220627.4                       1548.17
# ...                         ...                           ...
# ZOETERMEER           10314442.0                     253068.50
# ZUID-BEIJERLAND        305923.0                       6940.71
# ZUIDLAND               409632.0                       9591.99
# ZWARTEWAAL             200555.0                       4185.68
# ZWIJNDRECHT           2616741.0                      67342.81
#
# [2430 rows x 2 columns]

# %%
dg11111=dg1111.append(dg4)

# %%
dg11111
# Out:
#                  annual_consume  annual_consume_lowtarif_perc
# city
# ALMELO                6109311.0                     130584.84
# ENTER                    4122.0                         89.47
# GOOR                  1119848.0                      25675.84
# OLDENZAAL             3006420.0                      62182.08
# 'S GRAVENMOER          220627.4                       1548.17
# ...                         ...                           ...
# ZOETERMEER           10314442.0                     253068.50
# ZUID-BEIJERLAND        305923.0                       6940.71
# ZUIDLAND               409632.0                       9591.99
# ZWARTEWAAL             200555.0                       4185.68
# ZWIJNDRECHT           2616741.0                      67342.81
#
# [2695 rows x 2 columns]

# %%
dg11111.shape
# Out:
# (2695, 2)

# %%
dg11111.duplicated(subset=None, keep='first')
# Out:
# city
# ALMELO             False
# ENTER              False
# GOOR               False
# OLDENZAAL          False
# 'S GRAVENMOER      False
#                    ...
# ZOETERMEER          True
# ZUID-BEIJERLAND     True
# ZUIDLAND            True
# ZWARTEWAAL          True
# ZWIJNDRECHT         True
# Length: 2695, dtype: bool

# %%
dg = dg11111.groupby('city').sum()

# %%
dg
# Out:
#                 annual_consume  annual_consume_lowtarif_perc
# city
# 'S GRAVENMOER        220627.40                       1548.17
# 'S-GRAVELAND         212734.00                       1842.42
# 'S-GRAVENDEEL       1376762.00                      34182.60
# 'S-GRAVENHAGE      80072851.00                    1502911.99
# 'S-GRAVENZANDE        16824.00                        127.28
# ...                        ...                           ...
# ZWIJNDRECHT         5233482.00                     134685.62
# ZWINDEREN             72314.23                        467.22
# ZWOLLE             10652261.29                     107367.47
# Zwaagdijk-Oost         5889.00                         61.70
# loo                    4607.00                         46.15
#
# [2377 rows x 2 columns]

# %%
del dg['annual_consume_lowtarif_perc']

# %%
dg['year'] = pd.Series([2018 for x in range(len(dg.index))])
dg
# Out:
#                 annual_consume  year
# city
# 'S GRAVENMOER        220627.40   NaN
# 'S-GRAVELAND         212734.00   NaN
# 'S-GRAVENDEEL       1376762.00   NaN
# 'S-GRAVENHAGE      80072851.00   NaN
# 'S-GRAVENZANDE        16824.00   NaN
# ...                        ...   ...
# ZWIJNDRECHT         5233482.00   NaN
# ZWINDEREN             72314.23   NaN
# ZWOLLE             10652261.29   NaN
# Zwaagdijk-Oost         5889.00   NaN
# loo                    4607.00   NaN
#
# [2377 rows x 2 columns]

# %%
dg.to_excel("2018list.xlsx")

# %%
dg = dg[dg['annual_consume'].between(10000000, 5000000000)]
dg
# Out:
#                annual_consume  year
# city
# 'S-GRAVENHAGE     80072851.00   NaN
# ALMERE            17436187.00   NaN
# AMERSFOORT        20654219.00   NaN
# AMSTERDAM         55010230.00   NaN
# APELDOORN         12695430.00   NaN
# ARNHEM            13698976.00   NaN
# BREDA             12109094.16   NaN
# DELFT             15353120.00   NaN
# DORDRECHT         15105354.00   NaN
# EINDHOVEN         17574828.49   NaN
# ENSCHEDE          13457011.32   NaN
# GOUDA             11703052.00   NaN
# GRONINGEN         16091276.29   NaN
# HAARLEM           13119663.00   NaN
# NIEUWEGEIN        11407586.00   NaN
# NIJMEGEN          13418777.00   NaN
# ROTTERDAM         72618164.00   NaN
# SCHIEDAM          12434858.00   NaN
# TILBURG           14302462.11   NaN
# UTRECHT           44919350.00   NaN
# VEENENDAAL        10831711.00   NaN
# ZEIST             10084962.00   NaN
# ZOETERMEER        20628884.00   NaN
# ZWOLLE            10652261.29   NaN

# %%
dgg=dg.reset_index()

# %%
dgg.sort_values("annual_consume")
# Out:
#              city  annual_consume  year
# 21          ZEIST     10084962.00   NaN
# 23         ZWOLLE     10652261.29   NaN
# 20     VEENENDAAL     10831711.00   NaN
# 14     NIEUWEGEIN     11407586.00   NaN
# 11          GOUDA     11703052.00   NaN
# 6           BREDA     12109094.16   NaN
# 17       SCHIEDAM     12434858.00   NaN
# 4       APELDOORN     12695430.00   NaN
# 13        HAARLEM     13119663.00   NaN
# 15       NIJMEGEN     13418777.00   NaN
# 10       ENSCHEDE     13457011.32   NaN
# 5          ARNHEM     13698976.00   NaN
# 18        TILBURG     14302462.11   NaN
# 8       DORDRECHT     15105354.00   NaN
# 7           DELFT     15353120.00   NaN
# 12      GRONINGEN     16091276.29   NaN
# 1          ALMERE     17436187.00   NaN
# 9       EINDHOVEN     17574828.49   NaN
# 22     ZOETERMEER     20628884.00   NaN
# 2      AMERSFOORT     20654219.00   NaN
# 19        UTRECHT     44919350.00   NaN
# 3       AMSTERDAM     55010230.00   NaN
# 16      ROTTERDAM     72618164.00   NaN
# 0   'S-GRAVENHAGE     80072851.00   NaN

# %%
dff=_merge_col = pd.merge(dgg, dfp, on='city')
dff
# Out:
#           city  annual_consume  year  population   surface (km2)   Density
# 0       ALMERE     17436187.00   NaN     196.9320         248.80   0.791527
# 1   AMERSFOORT     20654219.00   NaN     152.4810          37.05   4.115547
# 2    AMSTERDAM     55010230.00   NaN     821.7520         219.30   3.747159
# 3    EINDHOVEN     17574828.49   NaN     223.2090          88.92   2.510223
# 4     ENSCHEDE     13457011.32   NaN     158.5530         118.13   1.342191
# 5      HAARLEM     13119663.00   NaN     235.1410          32.09   7.327548
# 6     NIJMEGEN     13418777.00   NaN     170.6810          57.63   2.961669
# 7    ROTTERDAM     72618164.00   NaN     623.6520         324.10   1.924258
# 8      TILBURG     14302462.11   NaN     217.2590         142.70   1.522488
# 9      UTRECHT     44919350.00   NaN    1300.3658          63.86  20.362759
# 10  ZOETERMEER     20628884.00   NaN     124.0250          98.13   1.263885
# 11      ZWOLLE     10652261.29   NaN     123.8610         119.40   1.037362

# %%
import matplotlib.pyplot as plt

# %%
x = [72.8490,196.9320,152.4810,821.7520,158.5530,170.6810,31.8400,217.2590,1300.3658,124.0250,123.8610]
y = [6244759.16,17436187,20654219,55010230,13457011.32,13418777,3168476.67,14302462.11,44919350,20628884,10652261.29]

plt.scatter(x, y)
plt.xlabel("Density")
plt.ylabel("Annual consume in 2018")
plt.show()

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib as plt
from matplotlib import pyplot
#sns.regplot(x="Density", y="annual_consume", data=dff)
#plt.ylim(0,)
dff.plot.hist()
dff.plot.scatter(x='Density ', y='annual_consume')
# Out:
# <AxesSubplot:xlabel='Density ', ylabel='annual_consume'>

# %%
dff.to_excel("2018.xlsx")
